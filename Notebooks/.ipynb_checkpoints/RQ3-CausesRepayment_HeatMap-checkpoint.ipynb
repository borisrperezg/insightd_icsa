# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import pandas_profiling
import seaborn as sns
# %matplotlib inline
sns.set_style("darkgrid")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', None)

# %%
#df = pd.read_csv('/gdrive/My Drive/InsighTD-AnalisisColombia/EASE_Data4RQ3_4Jupyter.csv', sep="|", index_col=False)
df = pd.read_csv('Data_RQ3_Heatmap.csv', sep=";", index_col=False)
df.columns.tolist()
# Out:
# ['CAUSES', 'REPAYMENTS', 'FREQ']

# %%
df.head(20)
# Out:
#                                   CAUSES                       REPAYMENTS  \
# 0                           1ST DEADLINE                      REFACTORING
# 1                           1ST DEADLINE                   CODE REVIEWING
# 2                           1ST DEADLINE                   IMPROVE DESIGN
# 3                           1ST DEADLINE            ARCHITECTURAL CHANGES
# 4             2ND INAPPROPRIATE PLANNING                      REFACTORING
# 5             2ND INAPPROPRIATE PLANNING                   IMPROVE DESIGN
# 6             2ND INAPPROPRIATE PLANNING                SYSTEM RETIREMENT
# 7             2ND INAPPROPRIATE PLANNING                   CODE REVIEWING
# 8             2ND INAPPROPRIATE PLANNING  TECHNOLOGY/TOOL/PLATFORM CHANGE
# 9             2ND INAPPROPRIATE PLANNING       ADOPTION OF GOOD PRACTICES
# 10  3RD NOT EFFECTIVE PROJECT MANAGEMENT                      REFACTORING
# 11  3RD NOT EFFECTIVE PROJECT MANAGEMENT       ADOPTION OF GOOD PRACTICES
# 12  3RD NOT EFFECTIVE PROJECT MANAGEMENT                  IMPROVE TESTING
# 13  3RD NOT EFFECTIVE PROJECT MANAGEMENT            IMPROVE COMMUNICATION
# 14  3RD NOT EFFECTIVE PROJECT MANAGEMENT                                -
# 15  3RD NOT EFFECTIVE PROJECT MANAGEMENT           CONTROL AND MONITORING
# 16  3RD NOT EFFECTIVE PROJECT MANAGEMENT               CONTINUOS LEARNING
# 17  3RD NOT EFFECTIVE PROJECT MANAGEMENT   HIRING QUALIFIED PROFESSIONALS
# 18    4TH PRODUCING MORE WITHOUT QUALITY                      REFACTORING
# 19    4TH PRODUCING MORE WITHOUT QUALITY                   IMPROVE DESIGN
#
#     FREQ
# 0      3
# 1      2
# 2      2
# 3      1
# 4      4
# 5      2
# 6      1
# 7      1
# 8      1
# 9      1
# 10     2
# 11     2
# 12     1
# 13     1
# 14     1
# 15     1
# 16     1
# 17     1
# 18     4
# 19     3

# %%
df1 = df.pivot("CAUSES", "REPAYMENTS", "FREQ")

plt.figure(figsize = (15,4))

ax = sns.heatmap(df1, vmin=0, vmax=7, cmap="coolwarm", linewidths=.5, annot=True, fmt=".0f", robust=True)
ax.set_facecolor('xkcd:white')
ax.set_title("TOP 10 CAUSES VS MOST SELECTED PRACTICES ON TD REPAYMENT\n", fontsize=15, fontweight="bold")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (9.0, 0.0)
