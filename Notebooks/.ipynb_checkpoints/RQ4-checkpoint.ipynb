# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import pandas_profiling
import seaborn as sns
# %matplotlib inline
sns.set_style("darkgrid")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', None)

# %%
#df = pd.read_csv('/gdrive/My Drive/InsighTD-AnalisisColombia/EASE_Data4RQ3_4Jupyter.csv', sep="|", index_col=False)
df = pd.read_csv('Data_RQ3_Heatmap.csv', sep=";", index_col=False)
df.columns.tolist()
# Out:
# ['ROLE', 'CAUSES', 'REPAYMENTS', 'FREQ']

# %%
df.head(20)
# Out:
#          ROLE                      CAUSES  \
# 0   TECHNICAL                1ST DEADLINE
# 1   TECHNICAL                1ST DEADLINE
# 2   TECHNICAL                1ST DEADLINE
# 3   TECHNICAL                1ST DEADLINE
# 4   TECHNICAL                1ST DEADLINE
# 5   TECHNICAL                1ST DEADLINE
# 6   TECHNICAL                1ST DEADLINE
# 7   TECHNICAL                1ST DEADLINE
# 8   TECHNICAL                1ST DEADLINE
# 9   TECHNICAL                1ST DEADLINE
# 10  TECHNICAL                1ST DEADLINE
# 11  TECHNICAL                1ST DEADLINE
# 12  TECHNICAL                1ST DEADLINE
# 13  TECHNICAL                1ST DEADLINE
# 14  TECHNICAL                1ST DEADLINE
# 15  TECHNICAL                1ST DEADLINE
# 16  TECHNICAL                1ST DEADLINE
# 17  TECHNICAL                1ST DEADLINE
# 18  TECHNICAL                1ST DEADLINE
# 19  TECHNICAL  2ND INAPPROPRIATE PLANNING
#
#                                      REPAYMENTS  FREQ
# 0   DEFINITION OF SPRINTS FOR THE PAYMENT OF DT     1
# 1                             BACKLOG INCLUSION     1
# 2                                TIME EXTENSION     2
# 3                               IMPROVE TESTING     5
# 4                                   REFACTORING     9
# 5                                         CI/CD     1
# 6                                             -     4
# 7                                 USE OF MODELS     1
# 8        IMPROVEMENT IN REQUIREMENT ELICITATION     2
# 9                                        DEVOPS     1
# 10                           MANAGEMENT ACTIONS     2
# 11               HIRING QUALIFIED PROFESSIONALS     1
# 12                         REPAYMENT ACTIVITIES     4
# 13                RESTORE LOST DATA FROM BACKUP     1
# 14                 SWITCHING SOFTWARE SOLUTIONS     1
# 15                         PROJECT SCOPE CHANGE     1
# 16                   ADOPTION OF GOOD PRACTICES     2
# 17                               IMPROVE DESIGN     1
# 18                        IMPROVE DOCUMENTATION     2
# 19                                            -     3

# %%
dfA = df[df['ROLE']=='ARCHITECT']

# %%
df1 = dfA.pivot("CAUSES", "REPAYMENTS", "FREQ")

plt.figure(figsize = (15,4))

ax = sns.heatmap(df1, vmin=0, vmax=7, cmap="coolwarm", linewidths=.5, annot=True, fmt=".0f", robust=True)
ax.set_facecolor('xkcd:white')
ax.set_title("TOP 10 CAUSES VS MOST SELECTED PRACTICES ON TD REPAYMENT\nARCHITECT", fontsize=15, fontweight="bold")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (9.0, 0.0)

# %%
dfT = df[df['ROLE']=='TECHNICAL']

# %%
df2 = dfT.pivot("CAUSES", "REPAYMENTS", "FREQ")

plt.figure(figsize = (15,4))

ax = sns.heatmap(df2, vmin=0, vmax=7, cmap="coolwarm", linewidths=.5, annot=True, fmt=".0f", robust=True)
ax.set_facecolor('xkcd:white')
ax.set_title("TOP 10 CAUSES VS MOST SELECTED PRACTICES ON TD REPAYMENT\nTECHNICAL", fontsize=15, fontweight="bold")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (10.0, 0.0)

# %%
dfM = df[df['ROLE']=='MANAGEMENT']

# %%
df3 = dfM.pivot("CAUSES", "REPAYMENTS", "FREQ")

plt.figure(figsize = (15,4))

ax = sns.heatmap(df3, vmin=0, vmax=7, cmap="coolwarm", linewidths=.5, annot=True, fmt=".0f", robust=True)
ax.set_facecolor('xkcd:white')
ax.set_title("TOP 10 CAUSES VS MOST SELECTED PRACTICES ON TD REPAYMENT\nMANAGEMENT", fontsize=15, fontweight="bold")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (10.0, 0.0)
